# %%
import urllib3
import certifi
import json
import pandas as pd


"""#######################################

USE PRH's BUSINESS INFORMATION API TO FETCH COMPANY DATA
https://avoindata.prh.fi/ytj_en.html

1. The application will fetch data for the companies that are defined
in yritykset.csv -file.

2. Flatten the json data into a dataframe

3. Append the flattened data into a PRH_data dataframe

4. Convert the PRH_data dataframe into a csv-file and save it to the workspace folder

##########################################"""


# Import yritykset.csv that contains name of companies
yritykset = pd.DataFrame(pd.read_csv("yritykset.csv", sep="\;", decimal=","))


# Define dataframe for the flattened data
PRH_data = pd.DataFrame(columns=["dataType",
                                        "businessId",
                                        "name",
                                        "companyForm",
                                        "companyForm2",
                                        "registrationDate",
                                        "endDate",
                                        "businessLines",
                                        "street",
                                        "postCode",
                                        "city",
                                        "country",
                                        "contactDetails",
                                        "contactDetailsType"])


# Create a loop that goes throug the company names one by one
for i in range(len(yritykset)):
        name = yritykset.loc[i, "Nimi"].replace(" ", "%20")
        name = name.replace("&", "%26")

        url = "https://avoindata.prh.fi/bis/v1?totalResults=false&name="+name

        print(url)


        # Fetch data using PRH API
        http = urllib3.PoolManager(
                cert_reqs="CERT_REQUIRED",
                ca_certs=certifi.where())

        r = http.request("GET", url)
        r.status

        data = json.loads(r.data.decode("utf-8"))


        # Use json_normalize() to flatten Json structures into Pandas DataFrames (tabular form)
        # If there are keyerrors (no data), empty dataframe will be provided
        while True:
                try:
                        df_osoitteet = pd.json_normalize(data=data["results"], record_path=["addresses"], meta=["businessId","name","registrationDate","companyForm"], record_prefix="_", errors="ignore")
                except(KeyError):
                        df_osoitteet = pd.DataFrame([])
                break

        while True:
                try:
                        df_yhteystiedot = pd.json_normalize(data=data["results"], record_path=["contactDetails"], meta=["businessId","name","registrationDate","companyForm"], record_prefix="_", errors="ignore")
                except(KeyError):
                        df_yhteystiedot = pd.DataFrame([])
                break

        while True:
                try:
                        df_yritysmuoto = pd.json_normalize(data=data["results"], record_path=["companyForms"], meta=["businessId","name","registrationDate","companyForm"], record_prefix="_", errors="ignore")
                except(KeyError):
                        df_yritysmuoto = pd.DataFrame([])
                break

        while True:
                try:
                        df_liiketoiminta = pd.json_normalize(data=data["results"], record_path=["businessLines"], meta=["businessId","name","registrationDate","companyForm"], record_prefix="_", errors="ignore")
                except(KeyError):
                        df_liiketoiminta = pd.DataFrame([])
                break

        # Create loops that goes through each dataframe and append data into the PRH_data dataframe
        for i in range(len(df_yritysmuoto)):
                PRH_data = PRH_data.append({"dataType":"companyForms" ,
                                                "businessId":df_yritysmuoto.loc[i,"businessId"],
                                                "name":df_yritysmuoto.loc[i,"name"],
                                                "companyForm":df_yritysmuoto.loc[i,"_name"],
                                                "companyForm2":df_yritysmuoto.loc[i,"_type"],
                                                "registrationDate":df_yritysmuoto.loc[i,"_registrationDate"],
                                                "endDate":df_yritysmuoto.loc[i,"_endDate"]},
                                                ignore_index=True)

        for i in range(len(df_liiketoiminta)):
                PRH_data = PRH_data.append({"dataType":"businessLines" ,
                                                "businessId":df_liiketoiminta.loc[i,"businessId"],
                                                "name":df_liiketoiminta.loc[i,"name"],
                                                "businessLines":df_liiketoiminta.loc[i,"_name"],
                                                "registrationDate":df_liiketoiminta.loc[i,"_registrationDate"],
                                                "endDate":df_liiketoiminta.loc[i,"_endDate"]},
                                                ignore_index=True)

        for i in range(len(df_osoitteet)):
                PRH_data = PRH_data.append({"dataType":"addresses" ,
                                                "businessId":df_osoitteet.loc[i,"businessId"],
                                                "name":df_osoitteet.loc[i,"name"],
                                                "registrationDate":df_osoitteet.loc[i,"_registrationDate"],
                                                "endDate":df_osoitteet.loc[i,"_endDate"],
                                                "street":df_osoitteet.loc[i,"_street"],
                                                "postCode":df_osoitteet.loc[i,"_postCode"],
                                                "city":df_osoitteet.loc[i,"_city"],
                                                "country":df_osoitteet.loc[i,"_country"]},
                                                ignore_index=True)

        for i in range(len(df_yhteystiedot)):
                PRH_data = PRH_data.append({"dataType":"contactDetails" ,
                                                "businessId":df_yhteystiedot.loc[i,"businessId"],
                                                "name":df_yhteystiedot.loc[i,"name"],
                                                "registrationDate":df_yhteystiedot.loc[i,"_registrationDate"],
                                                "endDate":df_yhteystiedot.loc[i,"_endDate"],
                                                "contactDetails":df_yhteystiedot.loc[i,"_value"],
                                                "contactDetailsType":df_yhteystiedot.loc[i,"_type"]},
                                                ignore_index=True)


print(PRH_data.head(10))


# Convert PRH_data into csv-file and save it to the workspace folder 
PRH_data.to_csv("prh_data", sep="\t", encoding="utf-8")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/data_science_env/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=3DI%20Akustiikkatuotteet
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=ABB%20Oy%20/Onninen
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ahlsell%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ahsell/Eurolan
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Algol%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=AM%20Lukkoasema%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Änäkkälän%20teräs%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Asennus-Kaiffarit%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Asennussuunta%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=BE%20Group%20+%20OKR
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=BE%20Group%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Berner%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=BOS%20Cleantec%20/%20Bierkühl%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Chiller%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Cramo%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Doka%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Duelco%20A/S
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Dynamo%20Henkilöstöratkaisut%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Eavenue%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ecosir%20Group%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=EKO-Expert%20KH%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=EL%20%26%20SITE%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Enviroprocess%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=EPS-Eristeet
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Eristysapu%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Esteri%20Pesulakoneet%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=FinnFoam%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=FläktGroup%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=FP%20Tuotteet%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Franke%20Medical%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Getinge%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Hatrick%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Heikkinen-Yhtiöt%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Hermetel%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Hilti%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Hilti%20Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Holmet%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=HSL%20Group%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=HV-Maanrakennus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=IMEDCO%20AG
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Jaatimet%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Jarkimo%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Jeld-Wen%20Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kangasalan%20Pumppauskeskus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kaskipuu%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Katman%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kavika%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kenset%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=KeraGroup%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kiimingin%20Eristys%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kiimingin%20Kaluste%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kinex%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Knorring%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Koja%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kojair%20Tech%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kolmeks%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kone%20Hissit%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Koralli-Tuote%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kuivatuote%20Jurvanen%20ja%20Havo%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kuljetuspolar%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Kymsol%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Laattapiste%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Länsi-Rajan%20Rakennussaneeraus
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Lassila%20%26%20Tikanoja%20Oyj
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Leinolift%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Lujabetoni%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Lujateko%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Lymet%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Maalausliike%20Haanpää%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Caverion%20Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Maguet%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Medifin%20Healthcare%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Medihealth%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Mediq%20Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Merivaara%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Mestarinikkarit%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Miele%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Mitta%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Muottikolmio%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Muovilami%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Muuraus%20Nahkala%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Muurausliike%20Sami%20Vanne%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=NCC%20Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Neagen%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Neptolux%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nokian%20Profiilit%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nord%20Raudoitus%20Oy%20%26%20Raudoitus%20P.Rintala%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nordic%20Jobcentre%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nordpel%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Norelco%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nostokonepalvelu%20AT%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nosturiasennus%20Virtanen
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Nosturiliike%20Sulkala%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Novosan%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=NQE%20Korjausrakentaminen
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ohutlevyverhous%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ojan%20Rauta%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=OMP-Konepaja%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oulun%20kosteustutkimus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oulun%20kuorirakenne%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oulun%20Telescan%20Oy%20/%20Bosch
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oy%20G.%20W.%20Berg%20%26%20co%20Ab
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oy%20Labcor%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oy%20Lindab%20Ab
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Oy%20Sika%20Finland%20Ab
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Palovex%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Peikko%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Peltisepänliike%20Nykänen%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Peltitarvike%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Penan%20Raudoitus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Peri%20Suomi%20LTD%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Petrat
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Pitomaalaus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Pohjois-Suomen%20tekniikkapalvelu%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=POK%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=POKO%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=PP-Fasadi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=ProRakenne%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Punta%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Rajaville%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ramirent%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=RAP%20Rakennus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Reka%20kaapelit%20/%20Onninen
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Renta%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=RK-lattiat%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=RKC%20Consturuction%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Rostek%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Roth%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=RRP%20Rakentajat%20Oy%20/%20Peltikarhut
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Rudus%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ruskon%20betoni%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ruukki%20Construction%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Sadex%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Sah-Ko%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Saint-Gobain%20Finland%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Serres%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Silentia%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Sisärakenne%20Kukkola%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Soinitilat
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Stark%20Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=STH-Steel%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Suomen%20Kiipeilytekniikka%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Suomen%20Palokatkomestarit
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Suomen%20Rakennuslogistiikka%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Suomen%20Valumestarit%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Swegon%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Teho-Tekniikka%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Teline-Kataja%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Teron%20Assembly%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Tuiran%20Kiinteistöpalvelut%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Turner%20door%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=UK-Muovi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Ulefos%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Väinö%20Korpinen%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Valtria%20Swiss%20AG
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Vivimedi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=VRJ%20Pohjois-Suomi%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=Würth%20Oy
# https://avoindata.prh.fi/bis/v1?totalResults=false&name=YTT%20Konepaja%20Oy
#         dataType businessId                       name      companyForm  \
# 0   companyForms  2925850-7  3DI Akustiikkatuotteet Oy  Limited company
# 1   companyForms  2925850-7  3DI Akustiikkatuotteet Oy       Osakeyhtiö
# 2   companyForms  2925850-7  3DI Akustiikkatuotteet Oy       Aktiebolag
# 3  businessLines  2925850-7  3DI Akustiikkatuotteet Oy              NaN
# 4  businessLines  2925850-7  3DI Akustiikkatuotteet Oy              NaN
# 5  businessLines  2925850-7  3DI Akustiikkatuotteet Oy              NaN
# 6      addresses  2925850-7  3DI Akustiikkatuotteet Oy              NaN
# 7   companyForms  0106435-6                   Algol Oy  Limited company
# 8   companyForms  0106435-6                   Algol Oy       Osakeyhtiö
# 9   companyForms  0106435-6                   Algol Oy       Aktiebolag
#
#   companyForm2 registrationDate endDate  \
# 0         None       2018-08-10    None
# 1           OY       2018-08-10    None
# 2           AB       2018-08-10    None
# 3          NaN       2018-05-31    None
# 4          NaN       2018-05-31    None
# 5          NaN       2018-05-31    None
# 6          NaN       2018-07-06    None
# 7         None             None    None
# 8           OY             None    None
# 9           AB             None    None
#
#                                        businessLines  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Agents involved in the sale of timber and buil...
# 4  Puutavaran ja rakennusmateriaalien agentuurito...
# 5        Provisionshandel med virke och byggmaterial
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                            street postCode  city country  \
# 0                                             NaN      NaN   NaN     NaN
# 1                                             NaN      NaN   NaN     NaN
# 2                                             NaN      NaN   NaN     NaN
# 3                                             NaN      NaN   NaN     NaN
# 4                                             NaN      NaN   NaN     NaN
# 5                                             NaN      NaN   NaN     NaN
# 6  Hantverkaregatan 7   SE-76130 Norrtälje SWEDEN     None  None    None
# 7                                             NaN      NaN   NaN     NaN
# 8                                             NaN      NaN   NaN     NaN
# 9                                             NaN      NaN   NaN     NaN
#
#   contactDetails contactDetailsType
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
# 5            NaN                NaN
# 6            NaN                NaN
# 7            NaN                NaN
# 8            NaN                NaN
# 9            NaN                NaN
